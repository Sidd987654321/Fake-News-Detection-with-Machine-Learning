# %%
import pandas as pds
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
true = pds.read_csv(r"C:\Users\user\Downloads\datasets\True.csv")

# %%
fake = pds.read_csv(r"C:\Users\user\Downloads\datasets\Fake.csv")

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
true.tail()
# Out:
#                                                    title  \
# 21412  'Fully committed' NATO backs new U.S. approach...
# 21413  LexisNexis withdrew two products from Chinese ...
# 21414  Minsk cultural hub becomes haven from authorities
# 21415  Vatican upbeat on possibility of Pope Francis ...
# 21416  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text    subject  \
# 21412  BRUSSELS (Reuters) - NATO allies on Tuesday we...  worldnews
# 21413  LONDON (Reuters) - LexisNexis, a provider of l...  worldnews
# 21414  MINSK (Reuters) - In the shadow of disused Sov...  worldnews
# 21415  MOSCOW (Reuters) - Vatican Secretary of State ...  worldnews
# 21416  JAKARTA (Reuters) - Indonesia will buy 11 Sukh...  worldnews
#
#                    date
# 21412  August 22, 2017
# 21413  August 22, 2017
# 21414  August 22, 2017
# 21415  August 22, 2017
# 21416  August 22, 2017

# %%
true.describe()
# Out:
#                                                     title  \
# count                                               21417
# unique                                              20826
# top     Factbox: Trump fills top jobs for his administ...
# freq                                                   14
#
#                                                      text       subject  \
# count                                               21417         21417
# unique                                              21192             2
# top     (Reuters) - Highlights for U.S. President Dona...  politicsNews
# freq                                                    8         11272
#
#                       date
# count                21417
# unique                 716
# top     December 20, 2017
# freq                   182

# %%
true.isnull()
# Out:
#        title   text  subject   date
# 0      False  False    False  False
# 1      False  False    False  False
# 2      False  False    False  False
# 3      False  False    False  False
# 4      False  False    False  False
# ...      ...    ...      ...    ...
# 21412  False  False    False  False
# 21413  False  False    False  False
# 21414  False  False    False  False
# 21415  False  False    False  False
# 21416  False  False    False  False
#
# [21417 rows x 4 columns]

# %%
fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
fake.tail()
# Out:
#                                                    title  \
# 23476  McPain: John McCain Furious That Iran Treated ...
# 23477  JUSTICE? Yahoo Settles E-mail Privacy Class-ac...
# 23478  Sunnistan: US and Allied ‘Safe Zone’ Plan to T...
# 23479  How to Blow $700 Million: Al Jazeera America F...
# 23480  10 U.S. Navy Sailors Held by Iranian Military ...
#
#                                                     text      subject  \
# 23476  21st Century Wire says As 21WIRE reported earl...  Middle-east
# 23477  21st Century Wire says It s a familiar theme. ...  Middle-east
# 23478  Patrick Henningsen  21st Century WireRemember ...  Middle-east
# 23479  21st Century Wire says Al Jazeera America will...  Middle-east
# 23480  21st Century Wire says As 21WIRE predicted in ...  Middle-east
#
#                    date
# 23476  January 16, 2016
# 23477  January 16, 2016
# 23478  January 15, 2016
# 23479  January 14, 2016
# 23480  January 12, 2016

# %%
fake.describe()
# Out:
#                                                     title   text subject  \
# count                                               23481  23481   23481
# unique                                              17903  17455       6
# top     MEDIA IGNORES Time That Bill Clinton FIRED His...           News
# freq                                                    6    626    9050
#
#                 date
# count          23481
# unique          1681
# top     May 10, 2017
# freq              46

# %%
fake.isnull()
# Out:
#        title   text  subject   date
# 0      False  False    False  False
# 1      False  False    False  False
# 2      False  False    False  False
# 3      False  False    False  False
# 4      False  False    False  False
# ...      ...    ...      ...    ...
# 23476  False  False    False  False
# 23477  False  False    False  False
# 23478  False  False    False  False
# 23479  False  False    False  False
# 23480  False  False    False  False
#
# [23481 rows x 4 columns]

# %%
true['label']= 1
fake ['label']= 0

# %%
news = pds.concat([fake,true], axis = 0)

# %%
news.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  label
# 0  December 31, 2017      0
# 1  December 31, 2017      0
# 2  December 30, 2017      0
# 3  December 29, 2017      0
# 4  December 25, 2017      0

# %%
news.tail()
# Out:
#                                                    title  \
# 21412  'Fully committed' NATO backs new U.S. approach...
# 21413  LexisNexis withdrew two products from Chinese ...
# 21414  Minsk cultural hub becomes haven from authorities
# 21415  Vatican upbeat on possibility of Pope Francis ...
# 21416  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text    subject  \
# 21412  BRUSSELS (Reuters) - NATO allies on Tuesday we...  worldnews
# 21413  LONDON (Reuters) - LexisNexis, a provider of l...  worldnews
# 21414  MINSK (Reuters) - In the shadow of disused Sov...  worldnews
# 21415  MOSCOW (Reuters) - Vatican Secretary of State ...  worldnews
# 21416  JAKARTA (Reuters) - Indonesia will buy 11 Sukh...  worldnews
#
#                    date  label
# 21412  August 22, 2017       1
# 21413  August 22, 2017       1
# 21414  August 22, 2017       1
# 21415  August 22, 2017       1
# 21416  August 22, 2017       1

# %%
news.describe()
# Out:
#               label
# count  44898.000000
# mean       0.477015
# std        0.499477
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000

# %%
news.shape
# Out:
# (44898, 5)

# %%
news = news.drop(['title','subject','date'],axis =1)

# %%
#reshuffle
news = news.sample(frac=1)
news.reset_index(drop =True,  inplace=True)
news.head()
# Out:
#                                                 text  label
# 0   GENERALLY, VENEZUELANS DO NOT EAT RABBITS AND...      0
# 1  When most presidents in the past have sent a m...      0
# 2  This random cop killing trend is almost like p...      0
# 3  UNITED NATIONS (Reuters) - Britain has asked f...      1
# 4  Not that it matters, but since it appears that...      0

# %%
sns.countplot(data=news, 
              x= 'label', 
              order=news['label'].value_counts().index ,palette='viridis')
plt.show()
# Out:
# C:\Users\Harsh\AppData\Local\Temp\ipykernel_13716\1532400345.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=news,

# %%
 from tqdm import tqdm
import re
import nltk
nltk.download('punkt')
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem.porter import PorterStemmer
from wordcloud import WordCloud
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Harsh\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Harsh\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.

# %%
def wordopt(text):
#lowercase 
  text=text.lower()
# urls
  text =re.sub(r'https?:??|@#$%%www.|','',text)
#puntuation
  text = re.sub(r'<>;''""()^!>','',text)
# remove digits
  text = re.sub(r'\d','',text)
#newline
  text = re.sub(r'\n','',text)
    #punctuaton
  text = re.sub(r'^\w\s','',text)  

  return text

# %%
news ['text'] = news['text'].apply(wordopt)

# %%
news ['text']
# Out:
# 0         generally, venezuelans do not eat rabbits and...
# 1        when most presidents in the past have sent a m...
# 2        this random cop killing trend is almost like p...
# 3        united nations (reuters) - britain has asked f...
# 4        not that it matters, but since it appears that...
#                                ...
# 44893    hey, everything is fair game in this war to wi...
# 44894    the nfl is in crisis mode after the massive ba...
# 44895    the fbi has actually received a voter suppress...
# 44896    moscow (reuters) - russia and saudi arabia hav...
# 44897    (reuters) - a lobbyist whose firm made payment...
# Name: text, Length: 44898, dtype: object

# %%
 x = news ['text']
y = news ['label']

# %%
x
# Out:
# 0         generally, venezuelans do not eat rabbits and...
# 1        when most presidents in the past have sent a m...
# 2        this random cop killing trend is almost like p...
# 3        united nations (reuters) - britain has asked f...
# 4        not that it matters, but since it appears that...
#                                ...
# 44893    hey, everything is fair game in this war to wi...
# 44894    the nfl is in crisis mode after the massive ba...
# 44895    the fbi has actually received a voter suppress...
# 44896    moscow (reuters) - russia and saudi arabia hav...
# 44897    (reuters) - a lobbyist whose firm made payment...
# Name: text, Length: 44898, dtype: object

# %%
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        1
# 4        0
#         ..
# 44893    0
# 44894    0
# 44895    0
# 44896    1
# 44897    1
# Name: label, Length: 44898, dtype: int64

# %%
 from sklearn.model_selection import train_test_split

# %%
x_train, x_test , y_train, y_test = train_test_split(x,y,test_size=0.3)

# %%
x_train.shape
# Out:
# (31428,)

# %%
x_test.shape
# Out:
# (13470,)

# %%
 from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorization = TfidfVectorizer(stop_words='english', max_features=50000, min_df=5, max_df=0.8)

# %%
xv_train = vectorization.fit_transform(x_train)

# %%
xv_test = vectorization.transform(x_test)

# %%
xv_train
# Out:
# <31428x32948 sparse matrix of type '<class 'numpy.float64'>'
# 	with 4598349 stored elements in Compressed Sparse Row format>

# %%
xv_test
# Out:
# <13470x32948 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1954975 stored elements in Compressed Sparse Row format>

# %%
from sklearn.linear_model import LogisticRegression

# %%
LR = LogisticRegression()

# %%
LR.fit(xv_train,y_train)
# Out:
# LogisticRegression()

# %%
pred_lr = LR.predict(xv_test)

# %%
LR.score(xv_test,y_test)
# Out:
# 0.9856718634001485

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test,pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99      7056
#            1       0.98      0.99      0.98      6414
#
#     accuracy                           0.99     13470
#    macro avg       0.99      0.99      0.99     13470
# weighted avg       0.99      0.99      0.99     13470

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc =DecisionTreeClassifier()

# %%
dtc.fit(xv_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred_dtc=dtc.predict(xv_test)

# %%
dtc.score(xv_test,y_test)
# Out:
# 0.9952487008166295

# %%
print(classification_report(y_test,pred_dtc))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7056
#            1       0.99      1.00      1.00      6414
#
#     accuracy                           1.00     13470
#    macro avg       1.00      1.00      1.00     13470
# weighted avg       1.00      1.00      1.00     13470

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier()

# %%
rfc.fit(xv_train,y_train)

# %%
pred_rfc=rfc.predict(xv_test)

# %%
rfc.score(xv_test,y_test)

# %%
print(classification_report(y_test,pred_rfc))

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gbc =GradientBoostingClassifier()

# %%
gbc.fit(xv_train,y_train)

# %%
pred_gbc=gbc.predict(xv_test)

# %%
gbc.score(xv_test,y_test)

# %%
print(classification_report(y_test,pred_gbc))

# %%
def output_label(n):
    if n == 0:
        return "FAKE"
    else:
        return "REAL"

# %%
def manual_testing(news):
    testing_news = {"test": [news]}
    new_def_test = pds.DataFrame(testing_news)
    new_def_test["test"] = new_def_test["test"].apply(wordopt)
    new_x_test = new_def_test["test"] 
    new_xv_test=vectorization.transform(new_x_test)
    pred_lr=LR.predict(new_xv_test)
    pred_dtc=dtc.predict(new_xv_test)
    pred_gbc=gbc.predict(new_xv_test)
    pred_rfc=rfc.predict(new_xv_test)
    return "\n\nLR Prediction:{} \nGBC Prediction :{} \nRFC Prediction: {}".format(output_label(pred_lr[0]) , output_label(pred_gbc[0]), 
                output_label(pred_rfc[0]))

# %%
news_article = str (input())

# %%
manual_testing(news_article)

# %%
news_article = str (input())

# %%
manual_testing(news_article)

# %%
news_article = str(input())

# %%
manual_testing(news_article)
